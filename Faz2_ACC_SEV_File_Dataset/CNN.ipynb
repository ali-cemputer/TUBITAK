# %%
import os
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, classification_report
import seaborn as sns

import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.keras import models, layers, optimizers, regularizers
from MultiLabel_File import utils
data_path = "datasets/CNN_ACC_SEV_V1.v2i.multiclass"

print("TensorFlow version:", tf.__version__)
print("GPU Build Info:", tf.sysconfig.get_build_info())
print("GPU Devices:", tf.config.list_physical_devices('GPU'))

# Bellek optimizasyonu (GPU kullanımı için)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)#TensorFlow’un başlangıçta minimum bellek tahsis etmesini ve yalnızca gerektiğinde bellek kullanmasını sağlar.
# Out:
# TensorFlow version: 2.10.1
# GPU Build Info: OrderedDict([('cpu_compiler', 'C:/Program Files (x86)/Microsoft Visual Studio/2019/Community/VC/Tools/MSVC/14.29.30133/bin/HostX64/x64/cl.exe'), ('cuda_compute_capabilities', ['sm_35', 'sm_50', 'sm_60', 'sm_70', 'sm_75', 'compute_80']), ('cuda_version', '64_112'), ('cudart_dll_name', 'cudart64_112.dll'), ('cudnn_dll_name', 'cudnn64_8.dll'), ('cudnn_version', '64_8'), ('is_cuda_build', True), ('is_rocm_build', False), ('is_tensorrt_build', False), ('msvcp_dll_names', 'msvcp140.dll,msvcp140_1.dll'), ('nvcuda_dll_name', 'nvcuda.dll')])
# GPU Devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def load_data(subset):
    """
    Dataseti içeri aktarır.
    :param subset: (test,train,valid)
    :return: csv dataset
    """
    csv_path = os.path.join(data_path, subset , "_classes.csv")
    df = pd.read_csv(csv_path)
    df.columns = df.columns.str.strip() #sütun adlarındaki boşlukları temizle.

    #filename sütununu path'e çevirme
    df['filename'] = df['filename'].apply(lambda x: os.path.normpath(os.path.join(data_path, subset, x)))
    return df

# %%
def create_dataset(df):
    images =df["filename"].values
    labels = df[["moderate-accident","no-accident","severe-accident"]].values.astype("float32")#tf ile uyumlu olması için float32 tipine dönüştürülür.

    dataset = tf.data.Dataset.from_tensor_slices((images, labels))#tf dataset

    dataset = dataset.map(lambda x, y: (preprocess_image(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE)# ön işleme için lambda fonk ve performans opt(paralel işleme)
    dataset = dataset.batch(32)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)#performans opt.
    return dataset

def preprocess_image(image_path):
    img = tf.io.read_file(image_path)#imageleri byte formatında okur, henüz çözümleme yapılmadı
    img = tf.image.decode_jpeg(img, channels=3)#resmi 3 kanallı tensöre çevrildi
    img = tf.image.resize(img, [224, 224])#standart boyutlaştırma
    img = img / 255.0# model learning için piksel değerlerini 0–1 aralığına çeker.
    return img

# %%
#Orjinal veriler
train_df = load_data("train")
valid_df = load_data("valid")
test_df = load_data("test")
print(f"{len(train_df)} train samples")
print(f"{len(valid_df)} validation samples")
print(f"{len(test_df)} test samples\n")

print(f"Ciddi Dereceli Kaza: {train_df['severe-accident'].sum()}")
print(f'Orta Dereceli Kaza: {train_df["moderate-accident"].sum()}')
print(f'Kaza Yok: {train_df["no-accident"].sum()}')

#Tensorflow Datasetler
train_df = create_dataset(train_df)
valid_df = create_dataset(valid_df)
test_df = create_dataset(test_df)
# Out:
# 7452 train samples
# 712 validation samples
# 354 test samples
#
# Ciddi Dereceli Kaza: 2382
# Orta Dereceli Kaza: 2439
# Kaza Yok: 2631

# %%
def create_model():
    model =models.Sequential([
        # İlk Convolutional blok
        layers.Conv2D(32, (3,3), activation="relu", input_shape=(224,224,3), padding="same"),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3,3), activation="relu", padding="same"),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)),#En önemli özellikler kalacak şekilde görüntüyü yarıya indirir.
        layers.Dropout(0.2),

        # İkinci Convolutional blok
        layers.Conv2D(64, (3,3), activation="relu", padding="same"),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3,3), activation="relu", padding="same"),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Dropout(0.3),

        # Üçüncü Convolutional blok
        layers.Conv2D(128, (3,3), activation="relu", padding="same"),
        layers.BatchNormalization(),
        layers.Conv2D(128, (3,3), activation="relu", padding="same"),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Dropout(0.4),

        # Dördüncü Convolutional Blok
        layers.Conv2D(256, (3,3), activation="relu", padding="same"),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Dropout(0.4),

        #Sınıflandırma Katmanı
        layers.GlobalAveragePooling2D(),
        layers.Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(3, activation="softmax"),
    ])

    # Model derleme
    model.compile(
        optimizer=optimizers.Adam(learning_rate=0.0005),
        loss='categorical_crossentropy',
        metrics=['accuracy',tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')],
    )
    return model
model = create_model()

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',#Doğrulama kaybını izle
        patience=10,#x epoch boyunca iyileşme olmazsa dur
        restore_best_weights=True,# En iyi ağırlıklara geri dön
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',# Doğrulama kaybı durursa
        factor=0.5,# Öğrenme oranını %x azalt
        patience=4,# x epoch boyunca iyileşme olmazsa lr düşür
        min_lr=1e-6, # En düşük learningrate oranı
        verbose = 1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        "best_model_files/best_CNN_model.h5",
        monitor='val_loss',
        save_best_only=True,#en düşük val_loss olduğunda kaydet.
        mode='min',
    )
]

# %%
history = model.fit(
    train_df,
    validation_data=valid_df,
    epochs=40,
    callbacks=my_callbacks,
    verbose=1,
)
# Out:
# Epoch 1/40
# 233/233 [==============================] - 62s 257ms/step - loss: 1.7607 - accuracy: 0.4090 - precision: 0.4184 - recall: 0.3374 - val_loss: 1.7547 - val_accuracy: 0.3343 - val_precision: 0.3206 - val_recall: 0.2935 - lr: 5.0000e-04
# Epoch 2/40
# 233/233 [==============================] - 60s 256ms/step - loss: 1.5244 - accuracy: 0.4603 - precision: 0.4787 - recall: 0.3779 - val_loss: 1.6027 - val_accuracy: 0.3806 - val_precision: 0.3589 - val_recall: 0.3413 - lr: 5.0000e-04
# Epoch 3/40
# 233/233 [==============================] - 60s 256ms/step - loss: 1.3013 - accuracy: 0.5393 - precision: 0.5589 - recall: 0.4514 - val_loss: 1.2507 - val_accuracy: 0.4607 - val_precision: 0.5079 - val_recall: 0.3596 - lr: 5.0000e-04
# Epoch 4/40
# 233/233 [==============================] - 60s 256ms/step - loss: 1.1949 - accuracy: 0.5617 - precision: 0.5887 - recall: 0.4972 - val_loss: 1.5023 - val_accuracy: 0.4312 - val_precision: 0.4493 - val_recall: 0.3919 - lr: 5.0000e-04
# Epoch 5/40
# 233/233 [==============================] - 59s 255ms/step - loss: 1.0579 - accuracy: 0.6122 - precision: 0.6364 - recall: 0.5586 - val_loss: 1.5384 - val_accuracy: 0.4677 - val_precision: 0.4782 - val_recall: 0.4312 - lr: 5.0000e-04
# Epoch 6/40
# 233/233 [==============================] - 60s 255ms/step - loss: 1.0031 - accuracy: 0.6259 - precision: 0.6428 - recall: 0.5758 - val_loss: 0.9675 - val_accuracy: 0.6390 - val_precision: 0.6661 - val_recall: 0.5941 - lr: 5.0000e-04
# Epoch 7/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.9548 - accuracy: 0.6429 - precision: 0.6605 - recall: 0.6029 - val_loss: 0.9208 - val_accuracy: 0.6110 - val_precision: 0.6420 - val_recall: 0.5843 - lr: 5.0000e-04
# Epoch 8/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.8939 - accuracy: 0.6589 - precision: 0.6723 - recall: 0.6236 - val_loss: 0.8248 - val_accuracy: 0.7022 - val_precision: 0.7179 - val_recall: 0.6433 - lr: 5.0000e-04
# Epoch 9/40
# 233/233 [==============================] - 59s 255ms/step - loss: 0.8340 - accuracy: 0.6856 - precision: 0.6975 - recall: 0.6555 - val_loss: 0.8611 - val_accuracy: 0.6433 - val_precision: 0.6481 - val_recall: 0.6208 - lr: 5.0000e-04
# Epoch 10/40
# 233/233 [==============================] - 60s 257ms/step - loss: 0.7891 - accuracy: 0.7003 - precision: 0.7120 - recall: 0.6790 - val_loss: 0.7951 - val_accuracy: 0.7065 - val_precision: 0.7193 - val_recall: 0.6587 - lr: 5.0000e-04
# Epoch 11/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.7485 - accuracy: 0.7193 - precision: 0.7274 - recall: 0.7012 - val_loss: 0.6784 - val_accuracy: 0.7683 - val_precision: 0.7688 - val_recall: 0.7612 - lr: 5.0000e-04
# Epoch 12/40
# 233/233 [==============================] - 60s 257ms/step - loss: 0.6977 - accuracy: 0.7458 - precision: 0.7521 - recall: 0.7308 - val_loss: 0.6714 - val_accuracy: 0.7289 - val_precision: 0.7277 - val_recall: 0.7205 - lr: 5.0000e-04
# Epoch 13/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.6346 - accuracy: 0.7703 - precision: 0.7776 - recall: 0.7590 - val_loss: 0.5397 - val_accuracy: 0.8301 - val_precision: 0.8307 - val_recall: 0.8272 - lr: 5.0000e-04
# Epoch 14/40
# 233/233 [==============================] - 59s 255ms/step - loss: 0.5830 - accuracy: 0.7927 - precision: 0.7976 - recall: 0.7826 - val_loss: 0.5534 - val_accuracy: 0.8160 - val_precision: 0.8261 - val_recall: 0.8076 - lr: 5.0000e-04
# Epoch 15/40
# 233/233 [==============================] - 60s 258ms/step - loss: 0.5050 - accuracy: 0.8331 - precision: 0.8378 - recall: 0.8257 - val_loss: 0.4736 - val_accuracy: 0.8525 - val_precision: 0.8571 - val_recall: 0.8427 - lr: 5.0000e-04
# Epoch 16/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.4300 - accuracy: 0.8654 - precision: 0.8682 - recall: 0.8618 - val_loss: 0.4126 - val_accuracy: 0.8624 - val_precision: 0.8634 - val_recall: 0.8610 - lr: 5.0000e-04
# Epoch 17/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.3804 - accuracy: 0.8853 - precision: 0.8886 - recall: 0.8812 - val_loss: 0.3771 - val_accuracy: 0.8876 - val_precision: 0.8887 - val_recall: 0.8862 - lr: 5.0000e-04
# Epoch 18/40
# 233/233 [==============================] - 60s 257ms/step - loss: 0.3245 - accuracy: 0.9082 - precision: 0.9109 - recall: 0.9054 - val_loss: 0.3264 - val_accuracy: 0.9087 - val_precision: 0.9083 - val_recall: 0.9045 - lr: 5.0000e-04
# Epoch 19/40
# 233/233 [==============================] - 60s 257ms/step - loss: 0.2646 - accuracy: 0.9282 - precision: 0.9301 - recall: 0.9273 - val_loss: 0.2593 - val_accuracy: 0.9368 - val_precision: 0.9368 - val_recall: 0.9368 - lr: 5.0000e-04
# Epoch 20/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.2325 - accuracy: 0.9379 - precision: 0.9388 - recall: 0.9369 - val_loss: 0.4244 - val_accuracy: 0.8975 - val_precision: 0.8984 - val_recall: 0.8947 - lr: 5.0000e-04
# Epoch 21/40
# 233/233 [==============================] - 60s 255ms/step - loss: 0.2213 - accuracy: 0.9410 - precision: 0.9427 - recall: 0.9399 - val_loss: 0.3357 - val_accuracy: 0.9115 - val_precision: 0.9137 - val_recall: 0.9073 - lr: 5.0000e-04
# Epoch 22/40
# 233/233 [==============================] - 60s 255ms/step - loss: 0.1858 - accuracy: 0.9518 - precision: 0.9532 - recall: 0.9502 - val_loss: 0.2282 - val_accuracy: 0.9452 - val_precision: 0.9466 - val_recall: 0.9452 - lr: 5.0000e-04
# Epoch 23/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.1697 - accuracy: 0.9580 - precision: 0.9595 - recall: 0.9573 - val_loss: 0.2502 - val_accuracy: 0.9298 - val_precision: 0.9298 - val_recall: 0.9298 - lr: 5.0000e-04
# Epoch 24/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.1480 - accuracy: 0.9638 - precision: 0.9645 - recall: 0.9632 - val_loss: 0.1731 - val_accuracy: 0.9649 - val_precision: 0.9649 - val_recall: 0.9649 - lr: 5.0000e-04
# Epoch 25/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.1480 - accuracy: 0.9577 - precision: 0.9596 - recall: 0.9568 - val_loss: 0.2968 - val_accuracy: 0.9228 - val_precision: 0.9225 - val_recall: 0.9199 - lr: 5.0000e-04
# Epoch 26/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.1229 - accuracy: 0.9687 - precision: 0.9694 - recall: 0.9683 - val_loss: 0.1474 - val_accuracy: 0.9691 - val_precision: 0.9691 - val_recall: 0.9691 - lr: 5.0000e-04
# Epoch 27/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.1102 - accuracy: 0.9728 - precision: 0.9727 - recall: 0.9724 - val_loss: 0.1644 - val_accuracy: 0.9677 - val_precision: 0.9704 - val_recall: 0.9677 - lr: 5.0000e-04
# Epoch 28/40
# 233/233 [==============================] - 59s 255ms/step - loss: 0.1076 - accuracy: 0.9732 - precision: 0.9737 - recall: 0.9724 - val_loss: 0.1844 - val_accuracy: 0.9607 - val_precision: 0.9607 - val_recall: 0.9607 - lr: 5.0000e-04
# Epoch 29/40
# 233/233 [==============================] - 59s 255ms/step - loss: 0.1066 - accuracy: 0.9701 - precision: 0.9704 - recall: 0.9693 - val_loss: 0.1727 - val_accuracy: 0.9733 - val_precision: 0.9733 - val_recall: 0.9719 - lr: 5.0000e-04
# Epoch 30/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.0810 - accuracy: 0.9817 - precision: 0.9821 - recall: 0.9813 - val_loss: 0.1119 - val_accuracy: 0.9789 - val_precision: 0.9789 - val_recall: 0.9789 - lr: 5.0000e-04
# Epoch 31/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.0905 - accuracy: 0.9783 - precision: 0.9788 - recall: 0.9780 - val_loss: 0.1275 - val_accuracy: 0.9747 - val_precision: 0.9747 - val_recall: 0.9747 - lr: 5.0000e-04
# Epoch 32/40
# 233/233 [==============================] - 59s 255ms/step - loss: 0.0745 - accuracy: 0.9830 - precision: 0.9832 - recall: 0.9827 - val_loss: 0.1336 - val_accuracy: 0.9635 - val_precision: 0.9635 - val_recall: 0.9635 - lr: 5.0000e-04
# Epoch 33/40
# 233/233 [==============================] - 59s 255ms/step - loss: 0.0835 - accuracy: 0.9795 - precision: 0.9796 - recall: 0.9789 - val_loss: 0.4129 - val_accuracy: 0.8989 - val_precision: 0.8989 - val_recall: 0.8989 - lr: 5.0000e-04
# Epoch 34/40
# 233/233 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9824 - precision: 0.9827 - recall: 0.9822
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 233/233 [==============================] - 59s 255ms/step - loss: 0.0742 - accuracy: 0.9824 - precision: 0.9827 - recall: 0.9822 - val_loss: 0.1569 - val_accuracy: 0.9677 - val_precision: 0.9677 - val_recall: 0.9663 - lr: 5.0000e-04
# Epoch 35/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.0513 - accuracy: 0.9910 - precision: 0.9913 - recall: 0.9910 - val_loss: 0.1112 - val_accuracy: 0.9817 - val_precision: 0.9817 - val_recall: 0.9817 - lr: 2.5000e-04
# Epoch 36/40
# 233/233 [==============================] - 60s 257ms/step - loss: 0.0406 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - val_loss: 0.1081 - val_accuracy: 0.9775 - val_precision: 0.9775 - val_recall: 0.9775 - lr: 2.5000e-04
# Epoch 37/40
# 233/233 [==============================] - 60s 257ms/step - loss: 0.0411 - accuracy: 0.9915 - precision: 0.9915 - recall: 0.9915 - val_loss: 0.1159 - val_accuracy: 0.9817 - val_precision: 0.9817 - val_recall: 0.9817 - lr: 2.5000e-04
# Epoch 38/40
# 233/233 [==============================] - 60s 256ms/step - loss: 0.0354 - accuracy: 0.9945 - precision: 0.9946 - recall: 0.9944 - val_loss: 0.1018 - val_accuracy: 0.9789 - val_precision: 0.9789 - val_recall: 0.9789 - lr: 2.5000e-04
# Epoch 39/40
# 233/233 [==============================] - 60s 255ms/step - loss: 0.0354 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9932 - val_loss: 0.1129 - val_accuracy: 0.9775 - val_precision: 0.9775 - val_recall: 0.9775 - lr: 2.5000e-04
# Epoch 40/40
# 233/233 [==============================] - 66s 283ms/step - loss: 0.0323 - accuracy: 0.9942 - precision: 0.9944 - recall: 0.9942 - val_loss: 0.1077 - val_accuracy: 0.9803 - val_precision: 0.9803 - val_recall: 0.9803 - lr: 2.5000e-04

# %%
# Eğitim sonuçlarını görselleştir
plt.figure(figsize=(12, 4))#12X4 LÜK GRAFİK PENCERESİ OLUŞTUR.

#Accuracy Greafiği
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Eğitim Doğruluğu')
plt.plot(history.history['val_accuracy'], label='Doğrulama Doğruluğu')
plt.title('Model Doğruluğu')
plt.xlabel('Epoch')
plt.ylabel('Doğruluk')
plt.legend()

#Loss grafiği
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.title('Model Kaybı')
plt.xlabel('Epoch')
plt.ylabel('Kayıp')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_true = []
y_pred = []
y_proba = []

class_names = ['Moderate Accident', 'Severe Accident', 'No Accident']

for images, labels in test_df:
    probs = model.predict(images, verbose =0)#verbose ile çıktı gösterilmez.
    preds = np.argmax(probs, axis=1)
    trues = np.argmax(labels.numpy(), axis=1)

    y_proba.extend(probs)
    y_true.extend(trues)
    y_pred.extend(preds)

y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_proba = np.array(y_proba)

acc = accuracy_score(y_true, y_pred)
f1_score = f1_score(y_true, y_pred, average='weighted')
roc_auc = roc_auc_score(tf.one_hot(y_true, len(class_names)), y_proba, multi_class='ovr')

print(f"Accuracy: {acc:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print(f"ROC-AUC Score: {roc_auc:.4f}")

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Tahmin")
plt.ylabel("Gerçek")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# Her sınıf için detaylı metrikler
print("\nSınıf Bazlı Performans:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Accuracy: 0.9831
# F1 Score: 0.9830
# ROC-AUC Score: 0.9998
# Sınıf Bazlı Performans:
#                    precision    recall  f1-score   support
#
# Moderate Accident       0.98      1.00      0.99       103
#   Severe Accident       0.98      0.97      0.98       129
#       No Accident       0.98      0.98      0.98       122
#
#          accuracy                           0.98       354
#         macro avg       0.98      0.98      0.98       354
#      weighted avg       0.98      0.98      0.98       354
